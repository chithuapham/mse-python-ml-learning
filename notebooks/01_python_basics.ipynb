# %%
print("Hello World")

name = "Chi Thua"

print(name)

for i in range(5):
    print(i)
# Out:
# Hello World
# Chi Thua
# 0
# 1
# 2
# 3
# 4

# %%
print("Xin chào Jupyter")
# Out:
# Xin chào Jupyter
